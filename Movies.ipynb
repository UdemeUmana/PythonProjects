# %%
import pandas as pd
import numpy as np

# %%
#Importing my dataset
#the dropna() is used to drop any value that is not a number or not a time,etc
movies= pd.read_csv(r'c:\Users\Udeme Umana\Downloads\movies - movies (1).csv').dropna()

# %%
#Displaying the first five columns in your dataset
movies
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#                released  score      votes         director  \
# ...

# %%
#Displaying the number of rows and columns in my dataset
movies.shape
# Out:
# (5421, 14)

# %%
#Printing information about my dataset
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5421 entries, 0 to 7652
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5421 non-null   object
#  1   rating    5421 non-null   object
#  2   genre     5421 non-null   object
#  3   released  5421 non-null   object
#  4   score     5421 non-null   float64
#  5   votes     5421 non-null   float64
#  6   director  5421 non-null   object
#  7   writer    5421 non-null   object
#  8   star      5421 non-null   object
#  9   country   5421 non-null   object
#  10  budget    5421 non-null   float64
#  11  gross     5421 non-null   float64
#  12  company   5421 non-null   object
#  13  runtime   5421 non-null   float64
# dtypes: float64(5), object(9)
# memory usage: 635.3+ KB

# %%
#converting the the gross,budget,votes and runtime datatype to an integer
movies['gross']=movies['gross'].astype('int64')
movies['budget']=movies['budget'].astype('int64')
movies['votes']=movies['votes'].astype('int64')
movies['runtime']= movies['runtime'].astype('int64')

# %%
#Getting the year from the released field and storing it in a new column(year)
movies[['Date','year']]= movies['released'].str.split(',' ,expand = True)
movies
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#                released  score    votes         director  \
# ...

# %%
#describing basic statistics of the dataframe
movies.describe()
# Out:
#              score         votes        budget         gross      runtime
# count  5421.000000  5.421000e+03  5.421000e+03  5.421000e+03  5421.000000
# mean      6.392455  1.150661e+05  3.600917e+07  1.032297e+08   108.152739
# std       0.962730  1.844073e+05  4.157337e+07  1.873027e+08    18.115698
# min       1.900000  1.950000e+02  6.000000e+03  3.090000e+02    63.000000
# 25%       5.800000  1.900000e+04  1.000000e+07  1.073640e+07    95.000000
# 50%       6.500000  5.200000e+04  2.180000e+07  3.686941e+07   105.000000
# 75%       7.100000  1.290000e+05  4.500000e+07  1.124625e+08   118.000000
# max       9.300000  2.400000e+06  3.560000e+08  2.847246e+09   271.000000

# %%
#Displaying the last five rows of my dataset
movies.tail(50)
# Out:
#                                    name     rating      genre  \
# 7520                      What Men Want          R     Comedy
# 7521                       Pet Sematary          R     Horror
# 7522            47 Meters Down: Uncaged      PG-13  Adventure
# 7524                 Happy Death Day 2U      PG-13     Comedy
# 7525                Weathering with You      PG-13  Animation
# 7526                            The Kid          R  Biography
# 7528  The Lego Movie 2: The Second Part         PG  Animation
# 7529                       Child's Play          R      Drama
# 7533                              Dumbo         PG  Adventure
# 7534                         The Hustle      PG-13     Comedy
# 7536                              Shaft          R     Action
# 7537                      The Beach Bum          R     Comedy
# 7538                        The Kitchen          R     Action
# 7540                             Stuber          R     Action
# ...

# %%
#Finding the highest gross pay
movies['gross'].max()
# Out:
# 2847246203

# %%
#Finding the lowest gross pay
movies['gross'].min()
# Out:
# 309

# %%
#Getting the unique values from the rating columns in a list format
list(movies['rating'].unique())
# Out:
# ['R',
#  'PG',
#  'G',
#  'NC-17',
#  'Approved',
#  'Not Rated',
#  'PG-13',
#  'Unrated',
#  'X',
#  'TV-MA']

# %%
#Finding the country with the highest vote in movies
movies1= movies.groupby('country')['votes'].count().reset_index()
movies1.sort_values(by='votes',ascending = False)
# Out:
#                            country  votes
# 47                   United States   4319
# 46                  United Kingdom    492
# 6                           Canada    111
# 14                          France    105
# 15                         Germany     82
# 2                        Australia     42
# 26                           Japan     28
# 8                            China     26
# 16                       Hong Kong     24
# 22                         Ireland     21
# 24                           Italy     19
# 32                     New Zealand     18
# 40                           Spain     18
# 39                     South Korea     13
# 30                          Mexico     11
# 11                         Denmark     10
# 19                           India      8
# 10                  Czech Republic      7
# 41                          Sweden      5
# 4                          Belgium      4
# 37                          Russia      4
# ...

# %%
#Finding the genre that has the hihest vote
movies1= movies.groupby('genre')['votes'].sum().reset_index()
movies1.sort_values(by='votes',ascending = False)
# Out:
#         genre      votes
# 0      Action  231136224
# 4      Comedy  107651384
# 6       Drama   92781154
# 5       Crime   45377300
# 2   Animation   40859922
# 1   Adventure   40298643
# 3   Biography   36102759
# 9      Horror   20591700
# 10    Mystery    4533000
# 8     Fantasy    2540000
# 7      Family     692900
# 12     Sci-Fi     643700
# 11    Romance     338600
# 13   Thriller     220500
# 14    Western       5700

# %%
#Displaying movies that the country is the United State and the genre is comedy
movies[(movies['country']=='United States') & (movies['genre']=='Comedy')]
# Out:
#                                name rating   genre           released  score  \
# 3                         Airplane!     PG  Comedy       July 2, 1980    7.7
# 4                        Caddyshack      R  Comedy      July 25, 1980    7.3
# 17                           9 to 5     PG  Comedy  December 19, 1980    6.9
# 35                 Private Benjamin      R  Comedy   October 10, 1980    6.2
# 36            The Hollywood Knights      R  Comedy       May 30, 1980    6.3
# ...                             ...    ...     ...                ...    ...
# 7541  The Art of Racing in the Rain     PG  Comedy     August 9, 2019    7.6
# 7543     Where'd You Go, Bernadette  PG-13  Comedy    August 16, 2019    6.5
# 7547              Isn't It Romantic  PG-13  Comedy  February 13, 2019    5.9
# 7571                         Little  PG-13  Comedy     April 12, 2019    5.5
# 7579         A Madea Family Funeral  PG-13  Comedy      March 1, 2019    4.5
#
# ...

# %%
#Displaying the name of the movies and their budget in desc order to find the movie with the highest budget
name_budget= movies.groupby('name')['budget'].sum().reset_index()
name_budget.sort_values(by='budget',ascending = False)
# Out:
#                                          name     budget
# 388                         Avengers: Endgame  356000000
# 389                    Avengers: Infinity War  321000000
# 3644  Star Wars: Episode VIII - The Last Jedi  317000000
# 4388                            The Lion King  305000000
# 3236                               Robin Hood  300000000
# ...                                       ...        ...
# 4395                           The Living End      22769
# 2906                      Paranormal Activity      15000
# 1257                              El Mariachi       7000
# 3062                                   Primer       7000
# 1461                                Following       6000
#
# [5336 rows x 2 columns]

# %%
#sorting my dataset by the gross amount to find the country and movies name with the lowest gross amount
movies.sort_values('gross',ascending=True)
# Out:
#                                             name     rating   genre  \
# 3203                                  Trojan War      PG-13  Comedy
# 272                                     Parasite          R  Horror
# 3681                                Ginger Snaps  Not Rated   Drama
# 2434                  Philadelphia Experiment II      PG-13  Action
# 5640                                 Tanner Hall          R   Drama
# ...                                          ...        ...     ...
# 7244                      Avengers: Infinity War      PG-13  Action
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action
# 3045                                     Titanic      PG-13   Drama
# 7445                           Avengers: Endgame      PG-13  Action
# 5445                                      Avatar      PG-13  Action
#
#                released  score    votes             director  \
# 3203    October 1, 1997    5.7     5800         George Huang
# ...

# %% [markdown]
# # Data Visualization

# %%
year_viz = movies.pivot_table(index='year',values='votes',aggfunc='sum').round(2)
year_viz
# Out:
#           votes
# year
#  1905     21100
#  1980   3626261
#  1981   2294277
#  1982   3888496
#  1983   4240584
#  1984   5321879
#  1985   4968493
#  1986   4662689
#  1987   5613367
#  1988   5279477
#  1989   6103259
#  1990   8151394
#  1991   6699500
#  1992   6579700
#  1993   7667900
#  1994  14916500
#  1995  12740559
#  1996   9642600
#  1997  13630000
#  1998  14466900
#  1999  19028600
#  2000  15172300
#  2001  19569000
#  2002  19499200
#  2003  22916700
#  2004  22751522
#  2005  20525500
#  2006  22767300
#  2007  25321200
#  2008  25556500
#  2009  26235000
#  2010  26792500
#  2011  27530700
#  2012  29220700
#  2013  30786400
#  2014  29709100
#  2015  23414000
#  2016  23331000
#  2017  20529300
#  2018  16759800
#  2019  14160095
#  2020   1609100
#  2022     13000

# %%
year_viz.plot(kind='line',linewidth=2.0)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
genre_viz= movies.pivot_table(index='genre',values='votes',aggfunc='sum')
genre_viz
# Out:
#                votes
# genre
# Action     231136224
# Adventure   40298643
# Animation   40859922
# Biography   36102759
# Comedy     107651384
# Crime       45377300
# Drama       92781154
# Family        692900
# Fantasy      2540000
# Horror      20591700
# Mystery      4533000
# Romance       338600
# Sci-Fi        643700
# Thriller      220500
# Western         5700

# %%
genre_viz.plot(kind='bar',linewidth=10.0)
# Out:
# <AxesSubplot:xlabel='genre'>
